# %%
setwd('/home/other/jpf5265/DnDs-visualization/Hierarchical_Edge_Bundling_tree/demo_for_Judith')

# %%
# Switch to R
library(tidyverse)
library(viridis)
library(patchwork)
library(ggraph)
library(igraph)
library(RColorBrewer)
library(dplyr)
library(tidyr)

# %%
# Step1: Read in the raw taxonomy files for both Archaea and Bacteria
# Taxonomy for Archaea (Read in the raw taxonomy file)
archaea_taxonomy_raw <- read.csv('ar53_taxonomy_r214.tsv', sep = '\t', header = FALSE)
colnames(archaea_taxonomy_raw) <- c('Assembly ID', 'lineage')

# Taxonomy for Bacteria (Read in the raw taxonomy file)
bacteria_taxonomy_raw <- read.csv('bac120_taxonomy_r214.tsv', sep = '\t', header = FALSE)
colnames(bacteria_taxonomy_raw) <- c('Assembly ID', 'lineage')

# %%
# Step 2: Clean the archaea taxonomy raw data
archaea_taxonomy <- archaea_taxonomy_raw %>%
  mutate(`Assembly ID` = gsub("^.{2}_", "", `Assembly ID`)) %>%  # Remove first two characters and underscore
  mutate(root = "Root") %>%  # Add the "root" column with all values as "Root"
  relocate(root, .after = `Assembly ID`) %>%  # Place the "root" column after "Assembly ID"
  separate(lineage, into = c("superkingdom", "phylum", "class", "order", "family", "genus", "species"),
           sep = ";", remove = TRUE) %>%  # Split lineage into taxonomy columns
  mutate(across(superkingdom:species, ~ gsub("^[dpcfogs]__", "", .)))

# Clean the bacteria taxonomy raw data
bacteria_taxonomy <- bacteria_taxonomy_raw %>%
  mutate(`Assembly ID` = gsub("^.{2}_", "", `Assembly ID`)) %>%  # Remove first two characters and underscore
  mutate(root = "Root") %>%  # Add the "root" column with all values as "Root"
  relocate(root, .after = `Assembly ID`) %>%  # Place the "root" column after "Assembly ID"
  separate(lineage, into = c("superkingdom", "phylum", "class", "order", "family", "genus", "species"),
           sep = ";", remove = TRUE) %>%  # Split lineage into taxonomy columns
  mutate(across(superkingdom:species, ~ gsub("^[dpcfogs]__", "", .)))

# Append the archaea and bacteria taxonomy data
lineage_information_new <- rbind(archaea_taxonomy, bacteria_taxonomy)

# %%
# Export to CSV
write.csv(lineage_information_new, file = "lineage_information_new.csv", row.names = FALSE, quote = FALSE)

# %%
# Step 3: Clean the 'query_name' and 'match_name' columns in the 'fmh_omega_7_for_HEB_figure_further_filter_query_name_x' dataset

# Define file path
file_path <- "fmh_omega_7_for_HEB_figure_further_filter_query_name_x.csv"

# Read the CSV file
fmh_omega_7 <- read.csv(file_path, sep = ",", header = TRUE)


# Filter rows where 'query_name' and 'match_name' are in the column "Assembly ID" of lineage_information_new
fmh_omega_7_short <- fmh_omega_7[
  fmh_omega_7$query_name %in% lineage_information_new$`Assembly ID` &
  fmh_omega_7$match_name %in% lineage_information_new$`Assembly ID`,
]

# Select specific columns: 'query_name', 'match_name', and 'dN/dS'
fmh_omega_7_short <- fmh_omega_7_short[, c("query_name", "match_name", "dN.dS")]

# %%
# Export to CSV
write.csv(fmh_omega_7_short, file = "fmh_omega_7_short.csv", row.names = FALSE, quote = FALSE)

# %%
# Step 4: Clean taxonomy and dnds datasets, selecting columns that are needed
taxonomy <- read.csv('lineage_information_new.csv')
dnds <- read.csv('fmh_omega_7_short.csv')

dnds <- dnds %>%
  filter(!is.na(dN.dS)) %>%
  rename(from = query_name, to = match_name, dndsvalue = dN.dS) %>%
  select(from, to, dndsvalue)


# Keep only Assembly.ID present in dnds$query_name or dnds$match_name
taxonomy_selected <- taxonomy %>%
  filter(Assembly.ID %in% unique(c(dnds$from, dnds$to)))

# %%
# # Step 5: Check for mutual pairs such as from genome A to genome B and from genome B to genome A in dnds dataset
mutual_check <- merge(dnds, dnds, by.x = c("from", "to"), by.y = c("to", "from"))

# Output the result
if (nrow(mutual_check) > 0) {
  print("Mutual connections found:")
  print(mutual_check)
} else {
  print("No mutual connections found.")
}
# Out:
# [1] "No mutual connections found."

# %%
# # Step 6: # Find out all genomes ids that are in the isolated pair. 
# The isolated pair here means each genome in this pair only connects to other genomes that only exists in this pair

# Create an undirected graph from the edge list
g <- graph_from_data_frame(dnds, directed = FALSE)

# Find connected components
comps <- components(g)

# Get component sizes
component_sizes <- comps$csize

# Get the membership vector
membership <- comps$membership

# Find components of size 2 (which connects with one and only one other genome)
components_of_size_two <- which(component_sizes == 2)

# Initialize vector to store genome IDs in isolated pairs
isolated_genomes <- c()

# Loop through each component of size 2
for (comp in components_of_size_two) {
  # Get the nodes in this component
  nodes_in_comp <- names(membership[membership == comp])
  # Add them to isolated_genomes
  isolated_genomes <- c(isolated_genomes, nodes_in_comp)
}

# Remove duplicate entries
isolated_genomes <- unique(isolated_genomes)

# %%
# # Step 7: # Based on the dnds dataset, removing all species that contained isolated_genomes ID in Step 6 
# since we do not want to show gemones that connects only one another genome in the visualization
# filter dnds to keep the visulation clean (Optional in this demo, if we do apply this step, connect will be the same as dnds)

######################### Apply this step if we want to remove isolated genomes in the visualization #########################
# connect <- dnds[!(dnds$from %in% isolated_genomes), ]

# connect <- dnds[!(dnds$from %in% isolated_genomes), ] %>%
#   # filter((dndsvalue >= 0 & dndsvalue <= 0.9 | dndsvalue >= 1.1 & dndsvalue <= 3))
#   filter(dndsvalue > 0.8 & dndsvalue < 1)
#   # filter(dndsvalue > 1)
#############################################################################################################################
connect <- dnds

# %%
# Step 8: Merge taxonomy information with the 'connect' dataset to 
# ensure both genome A and genome B have taxonomy information for a given taxonomic level such as genus

# Merge taxonomy information for the 'from' column
connect_with_from <- connect %>%
  left_join(taxonomy_selected, by = c("from" = "Assembly.ID")) %>%
  rename(root_from = root, 
         superkingdom_from = superkingdom, 
         phylum_from = phylum, 
         class_from = class, 
         order_from = order, 
         family_from = family, 
         genus_from = genus, 
         species_from = species)

# Merge taxonomy information for the 'to' column
connect_with_taxonomy <- connect_with_from %>%
  left_join(taxonomy_selected, by = c("to" = "Assembly.ID")) %>%
  rename(root_to = root, 
         superkingdom_to = superkingdom, 
         phylum_to = phylum, 
         class_to = class, 
         order_to = order, 
         family_to = family, 
         genus_to = genus, 
         species_to = species)

connect_with_taxonomy_updated<-connect_with_taxonomy %>%
  filter(genus_from != "" & !is.na(genus_from),  # Ensure genus_from is not empty or NA
         genus_to != "" & !is.na(genus_to), # Ensure genus_to is not empty or NA
         superkingdom_from == superkingdom_to # Ensure the superkingdoms are the same
        #  superkingdom_from == 'Bacteria' &  superkingdom_to == 'Bacteria'   # Ensure both superkingdom_from and superkingdom_to are 'Bacteria'
        #  superkingdom_from == 'Archaea' &  superkingdom_to == 'Archaea'   # Ensure both superkingdom_from and superkingdom_to are 'Archaea'
         
         ) 

cat("Number of valid edges (with positions):", nrow(connect_with_taxonomy_updated), "\n")
# Out:
# Number of valid edges (with positions): 96

# %%
# Step 9: Clean the taxonomy_selected df to keep only the nodes (valid nodes) that are present 
# in the filtered connect df in Step 8
taxonomy_selected_final <- taxonomy_selected[taxonomy_selected$Assembly.ID %in% unique(c(connect_with_taxonomy_updated$from, connect_with_taxonomy_updated$to)), ]
cat("Number of valid nodes:", nrow(taxonomy_selected_final), "\n")
# Out:
# Number of valid nodes: 57

# %%
# Step 10: Create hierarcy and vertices for hierarchical edge bundling visualization

# Add a root column to the taxonomy data, reshape the data into long format
taxonomy_long <- taxonomy_selected_final %>%
  select(Assembly.ID, root, superkingdom, phylum, class, order, family, genus, species) %>%
  mutate(root = if_else(root == "cellular organisms", "Root", root)) %>%
      # Create hierarchical relationships
  pivot_longer(cols = c(root, superkingdom, phylum, class, order, family, genus, species, Assembly.ID),
               names_to = "level",
               values_to = "name") %>%
  mutate(genome_id = rep(taxonomy_selected_final$Assembly.ID, each = 9)) # 9 is the numbers of columns in taxonomy_selected

  # Create hierarchical relationships
hierarchy <- taxonomy_long %>%

  # sorting taxomomic level within each genome ("genome_id")
  arrange(genome_id, match(level, c("root", "superkingdom", "phylum", "class", "order", "family", "genus", "species", "Assembly.ID"))) %>%
  group_by(genome_id) %>%

  # from = lag(name): Take the value from the previous row in the column "name" and assigns it to a new column called from, 
  # to = name: Set the value in column "to" the value in the name column.
  mutate(from = lag(name), to = name)  %>%
  filter(!is.na(from)) %>%
  select(from, to, genome_id) %>%
  distinct() %>%
  ungroup() %>%
  distinct(from, to)

vertices <- data.frame(name = unique(c(as.character(hierarchy$from), as.character(hierarchy$to))))
nrow(vertices)
# Out:
# [1] 135

# %%
# Attempt 1:
set.seed(399)
library(ggraph)
library(igraph)
library(dplyr)


# Create the graph object
vertices <- data.frame(name = unique(c(as.character(hierarchy$from), as.character(hierarchy$to))), value = runif(nrow(vertices))) 
mygraph <- graph_from_data_frame(hierarchy, vertices = vertices)


from <- match(connect_with_taxonomy_updated$from, vertices$name)
to <- match(connect_with_taxonomy_updated$to, vertices$name)

# %%
# Step 11: Retain layout data for only the nodes that are connected by valid edges
# create the layout so we can feed to to get_con and manipulate the data frame directly for plotting
layout_data <- create_layout(mygraph, layout = 'dendrogram', circular = TRUE)

# # 'from' and 'to' are vectors of node indices or names
conn_function <- get_con(from = from, to = to)
conn_data_frame <- conn_function(layout_data)

# # # Add connection values to `conn_data_frame`. This is one of the key steps of getting the connections/dNdS values to match up with the actual plot
conn_data_frame$con.value <- connect_with_taxonomy_updated$dndsvalue[conn_data_frame$con.id]

# Remove invalid connections where genomes are not in connect_new
conn_data_frame <- conn_data_frame[!is.na(conn_data_frame$con.value), ]

sum(conn_data_frame$leaf == 'TRUE')
# Out:
# [1] 192

# %%
# Step 12: Determine the coordinates of the genus label
genome_coordinate<-unique(conn_data_frame[conn_data_frame$leaf == TRUE, c('name','x','y')])

genome_coordinate_info <- merge(
  genome_coordinate, 
  taxonomy_selected_final[, c("Assembly.ID", "phylum", "class", "order", "family", "genus", "species")],
  by.x = "name", 
  by.y = "Assembly.ID", 
  all.x = TRUE
)

# Function to calculate center coordinates for each genus
calculate_genus_centers <- function(data, taxonomy_level_column, x_column, y_column) {
  # Group by genus and calculate the mean x and y coordinates
  centers <- data %>%
    group_by(!!sym(taxonomy_level_column)) %>%
    summarise(
      center_x = mean(!!sym(x_column)),
      center_y = mean(!!sym(y_column)),
      .groups = 'drop'
    )
  return(centers)
}

taxonomy_level_column<-"genus" # Can change to any other taxonomy levels such as family


# Dynamically create the name for genus_centers
centers_name <- paste0(taxonomy_level_column, "_centers")

# Calculate centers and assign to dynamically named variable
assign(centers_name, calculate_genus_centers(genome_coordinate_info, 
                                             taxonomy_level_column = taxonomy_level_column, 
                                             x_column = "x", 
                                             y_column = "y"))

# nrow(genus_centers)

cat("Number of unique", taxonomy_level_column, "groups:", nrow(genus_centers), "\n")
# Out:
# Number of unique genus groups: 4

# %%
# Step 13a: Generate a graph based on genomes and their dN/dS values, labelling each dot on the circle represents a genome
ggraph(mygraph, layout = 'dendrogram', circular = TRUE) + 
  geom_conn_bundle(
    data = conn_data_frame, 
    alpha = 0.8, 
    width = 0.9, 
    aes(edge_colour = con.value)
  ) +  # Adjust edge colors based on `con.value`
  geom_node_text(
    aes(
      x = x * 1.15, 
      y = y * 1.15, 
      filter = leaf, 
      label = name
    ), 
    size = 2, 
    alpha = 1
  ) +  # Remove color from nodes
  geom_node_point(
    aes(
      filter = leaf, 
      x = x * 1.07, 
      y = y * 1.07
    ), 
    alpha = 0.8
  ) +  # Remove color from points
  scale_edge_colour_gradient2(
    low = "blue",    # Blue for negative values
    mid = "white",  # White for zero
    high = "red",  # Red for positive values
    midpoint = 1,  # Center of gradient
    name = "dnds value"
    
  ) +
  scale_size_continuous(range = c(1, 3)) +  # Size scale for node points
  theme_void() +
  expand_limits(x = c(-1.3, 1.3), y = c(-1.3, 1.3))
# Out:
# plot without title

# %%
# Step 13b: Labelling based on genus groups
ggraph(mygraph, layout = 'dendrogram', circular = TRUE) + 
  geom_conn_bundle(
    data = conn_data_frame, 
    alpha = 0.8, 
    width = 0.9, 
    aes(edge_colour = con.value)
  ) +  # Adjust edge colors based on `con.value`
  geom_text(
    data = genus_centers,  # Use the genus_centers dataframe
    aes(
      x = center_x * 1.15,  # Adjust x for genus labels
      y = center_y * 1.15,  # Adjust y for genus labels
      label = genus         # Use the genus column for labels
    ),
    size = 2, 
    alpha = 1
  ) +  # Remove color from points
  geom_node_point(
    aes(
      filter = leaf, 
      x = x * 1.07, 
      y = y * 1.07
    ), 
    alpha = 0.8
  ) +  # Remove color from points
  scale_edge_colour_gradient2(
    low = "blue",    # Blue for negative values
    mid = "white",  # White for zero
    high = "red",  # Red for positive values
    midpoint = 1,  # Center of gradient
    name = "dnds value"
    
  ) +
  scale_size_continuous(range = c(1, 3)) +  # Size scale for node points
  theme_void() +
  expand_limits(x = c(-1.3, 1.3), y = c(-1.3, 1.3))
# Out:
# plot without title

# %%
genome_coordinate_info
# Out:
#    name            x             y           phylum         class
# 1  GCA_023426545.1  5.508776e-02  0.99848152 Myxococcota    Myxococcia
# 2  GCF_000009605.1  9.694003e-01 -0.24548549 Pseudomonadota Gammaproteobacteria
# 3  GCF_000022605.2  8.922542e-01 -0.45153336 Bacteroidota   Bacteroidia
# 4  GCF_000195595.1 -9.544050e-01  0.29851481 Actinomycetota Actinomycetia
# 5  GCF_000225445.1  9.365112e-01 -0.35063756 Pseudomonadota Gammaproteobacteria
# 6  GCF_000233435.1  8.371665e-01 -0.54694816 Bacteroidota   Bacteroidia
# 7  GCF_000236405.1  7.719167e-01 -0.63572375 Bacteroidota   Bacteroidia
# 8  GCF_000262715.1  6.972968e-01 -0.71678251 Bacteroidota   Bacteroidia
# 9  GCF_000280925.3  1.645946e-01  0.98636130 Myxococcota    Myxococcia
# 10 GCF_000348805.1  6.142127e-01 -0.78914051 Bacteroidota   Bacteroidia
# 11 GCF_000471965.1  4.267764e-01 -0.90435716 Bacteroidota   Bacteroidia
# 12 GCF_001553935.1 -9.157733e-01  0.40169542 Actinomycetota Actinomycetia
# 13 GCF_001929375.1 -8.660254e-01  0.50000000 Actinomycetota Actinomycetia
# 14 GCF_001937445.1 -8.057651e-01  0.59223525 Actinomycetota Actinomycetia
# 15 GCF_001937665.1 -7.357239e-01  0.67728157 Actinomycetota Actinomycetia
# 16 GCF_001956585.1 -6.567520e-01  0.75410661 Actinomycetota Actinomycetia
# 17 GCF_002305895.1  2.721035e-01  0.96226800 Myxococcota    Myxococcia
# 18 GCF_003226855.1  3.246995e-01 -0.94581724 Bacteroidota   Bacteroidia
# 19 GCF_003268615.1  2.186811e-01 -0.97579638 Bacteroidota   Bacteroidia
# 20 GCF_003573915.1  1.100082e-01 -0.99393068 Bacteroidota   Bacteroidia
# 21 GCF_005696555.1 -5.698081e-01  0.82177782 Actinomycetota Actinomycetia
# 22 GCF_006402735.1  3.763094e-01  0.92649407 Myxococcota    Myxococcia
# 23 GCF_006546825.1 -4.759474e-01  0.87947375 Actinomycetota Actinomycetia
# 24 GCF_006546835.1 -3.763094e-01  0.92649407 Actinomycetota Actinomycetia
# 25 GCF_006636215.1  4.759474e-01  0.87947375 Myxococcota    Myxococcia
# 26 GCF_010894405.1  5.698081e-01  0.82177782 Myxococcota    Myxococcia
# 27 GCF_010894435.1  6.567520e-01  0.75410661 Myxococcota    Myxococcia
# 28 GCF_010894475.1  7.357239e-01  0.67728157 Myxococcota    Myxococcia
# 29 GCF_010998615.1  8.057651e-01  0.59223525 Myxococcota    Myxococcia
# 30 GCF_011290385.1  6.123234e-17 -1.00000000 Bacteroidota   Bacteroidia
# 31 GCF_011752065.1 -2.721035e-01  0.96226800 Actinomycetota Actinomycetia
# 32 GCF_012933655.1  8.660254e-01  0.50000000 Myxococcota    Myxococcia
# 33 GCF_013116825.1  9.157733e-01  0.40169542 Myxococcota    Myxococcia
# 34 GCF_014251315.1 -1.100082e-01 -0.99393068 Bacteroidota   Bacteroidia
# 35 GCF_014251335.1 -2.186811e-01 -0.97579638 Bacteroidota   Bacteroidia
# 36 GCF_014251555.1 -3.246995e-01 -0.94581724 Bacteroidota   Bacteroidia
# 37 GCF_014251575.1 -4.267764e-01 -0.90435716 Bacteroidota   Bacteroidia
# 38 GCF_014251595.1 -5.236729e-01 -0.85191941 Bacteroidota   Bacteroidia
# 39 GCF_014251635.1 -6.142127e-01 -0.78914051 Bacteroidota   Bacteroidia
# 40 GCF_014251695.1 -6.972968e-01 -0.71678251 Bacteroidota   Bacteroidia
# 41 GCF_014251715.1 -7.719167e-01 -0.63572375 Bacteroidota   Bacteroidia
# 42 GCF_014251755.1  5.236729e-01 -0.85191941 Bacteroidota   Bacteroidia
# 43 GCF_014251795.1 -8.371665e-01 -0.54694816 Bacteroidota   Bacteroidia
# 44 GCF_014251815.1 -8.922542e-01 -0.45153336 Bacteroidota   Bacteroidia
# 45 GCF_014251995.1 -9.365112e-01 -0.35063756 Bacteroidota   Bacteroidia
# 46 GCF_014252015.1 -9.694003e-01 -0.24548549 Bacteroidota   Bacteroidia
# 47 GCF_014252075.1 -9.905221e-01 -0.13735356 Bacteroidota   Bacteroidia
# 48 GCF_014252115.1 -9.996203e-01 -0.02755434 Bacteroidota   Bacteroidia
# 49 GCF_014252255.1 -9.965845e-01  0.08257935 Bacteroidota   Bacteroidia
# 50 GCF_014252295.1 -9.814515e-01  0.19171063 Bacteroidota   Bacteroidia
# 51 GCF_017301735.1  9.544050e-01  0.29851481 Myxococcota    Myxococcia
# 52 GCF_020037125.1  9.814515e-01  0.19171063 Myxococcota    Myxococcia
# 53 GCF_024198175.1  9.965845e-01  0.08257935 Myxococcota    Myxococcia
# 54 GCF_900101905.1  9.996203e-01 -0.02755434 Myxococcota    Myxococcia
# 55 GCF_900106535.1  9.905221e-01 -0.13735356 Myxococcota    Myxococcia
# 56 GCF_900323545.1 -1.645946e-01  0.98636130 Actinomycetota Actinomycetia
# 57 GCF_900637975.1 -5.508776e-02  0.99848152 Actinomycetota Actinomycetia
#    order            family             genus
# 1  Myxococcales     Myxococcaceae      Myxococcus
# 2  Enterobacterales Enterobacteriaceae Buchnera
# 3  Flavobacteriales Blattabacteriaceae Blattabacterium
# 4  Actinomycetales  Actinomycetaceae   Actinomyces
# 5  Enterobacterales Enterobacteriaceae Buchnera
# 6  Flavobacteriales Blattabacteriaceae Blattabacterium
# 7  Flavobacteriales Blattabacteriaceae Blattabacterium
# 8  Flavobacteriales Blattabacteriaceae Blattabacterium
# 9  Myxococcales     Myxococcaceae      Myxococcus
# 10 Flavobacteriales Blattabacteriaceae Blattabacterium
# 11 Flavobacteriales Blattabacteriaceae Blattabacterium
# 12 Actinomycetales  Actinomycetaceae   Actinomyces
# 13 Actinomycetales  Actinomycetaceae   Actinomyces
# 14 Actinomycetales  Actinomycetaceae   Actinomyces
# 15 Actinomycetales  Actinomycetaceae   Actinomyces
# 16 Actinomycetales  Actinomycetaceae   Actinomyces
# 17 Myxococcales     Myxococcaceae      Myxococcus
# 18 Flavobacteriales Blattabacteriaceae Blattabacterium
# 19 Flavobacteriales Blattabacteriaceae Blattabacterium
# 20 Flavobacteriales Blattabacteriaceae Blattabacterium
# 21 Actinomycetales  Actinomycetaceae   Actinomyces
# 22 Myxococcales     Myxococcaceae      Myxococcus
# 23 Actinomycetales  Actinomycetaceae   Actinomyces
# 24 Actinomycetales  Actinomycetaceae   Actinomyces
# 25 Myxococcales     Myxococcaceae      Myxococcus
# 26 Myxococcales     Myxococcaceae      Myxococcus
# 27 Myxococcales     Myxococcaceae      Myxococcus
# 28 Myxococcales     Myxococcaceae      Myxococcus
# 29 Myxococcales     Myxococcaceae      Myxococcus
# 30 Flavobacteriales Blattabacteriaceae Blattabacterium
# 31 Actinomycetales  Actinomycetaceae   Actinomyces
# 32 Myxococcales     Myxococcaceae      Myxococcus
# 33 Myxococcales     Myxococcaceae      Myxococcus
# 34 Flavobacteriales Blattabacteriaceae Blattabacterium
# 35 Flavobacteriales Blattabacteriaceae Blattabacterium
# 36 Flavobacteriales Blattabacteriaceae Blattabacterium
# 37 Flavobacteriales Blattabacteriaceae Blattabacterium
# 38 Flavobacteriales Blattabacteriaceae Blattabacterium
# 39 Flavobacteriales Blattabacteriaceae Blattabacterium
# 40 Flavobacteriales Blattabacteriaceae Blattabacterium
# 41 Flavobacteriales Blattabacteriaceae Blattabacterium
# 42 Flavobacteriales Blattabacteriaceae Blattabacterium
# 43 Flavobacteriales Blattabacteriaceae Blattabacterium
# 44 Flavobacteriales Blattabacteriaceae Blattabacterium
# 45 Flavobacteriales Blattabacteriaceae Blattabacterium
# 46 Flavobacteriales Blattabacteriaceae Blattabacterium
# 47 Flavobacteriales Blattabacteriaceae Blattabacterium
# 48 Flavobacteriales Blattabacteriaceae Blattabacterium
# 49 Flavobacteriales Blattabacteriaceae Blattabacterium
# 50 Flavobacteriales Blattabacteriaceae Blattabacterium
# 51 Myxococcales     Myxococcaceae      Myxococcus
# 52 Myxococcales     Myxococcaceae      Myxococcus
# 53 Myxococcales     Myxococcaceae      Myxococcus
# 54 Myxococcales     Myxococcaceae      Myxococcus
# 55 Myxococcales     Myxococcaceae      Myxococcus
# 56 Actinomycetales  Actinomycetaceae   Actinomyces
# 57 Actinomycetales  Actinomycetaceae   Actinomyces
#    species
# 1  Myxococcus sp023426545
# 2  Buchnera aphidicola_I
# 3  Blattabacterium sp000022605
# 4  Actinomyces sp000195595
# 5  Buchnera aphidicola_A
# 6  Blattabacterium sp000233435
# 7  Blattabacterium punctulatus
# 8  Blattabacterium sp000262715
# 9  Myxococcus hansupus
# 10 Blattabacterium cuenoti_B
# 11 Blattabacterium sp000471965
# 12 Actinomyces oris_A
# 13 Actinomyces oris_B
# 14 Actinomyces oris_C
# 15 Actinomyces oris_D
# 16 Actinomyces naeslundii
# 17 Myxococcus macrosporus
# 18 Blattabacterium sp003226855
# 19 Blattabacterium clevelandi
# 20 Blattabacterium cuenoti_A
# 21 Actinomyces oris_E
# 22 Myxococcus xanthus_A
# 23 Actinomyces oris
# 24 Actinomyces johnsonii
# 25 Myxococcus llanfairpwllgwyngyllgogerychwyrndrobwllllantysiliogogogochensis
# 26 Myxococcus caerfyrddinensis
# 27 Myxococcus trucidator
# 28 Myxococcus vastator
# 29 Myxococcus sp010998615
# 30 Blattabacterium sp011290385
# 31 Actinomyces sp011752065
# 32 Myxococcus fallax
# 33 Myxococcus xanthus_B
# 34 Blattabacterium cuenoti_AJ
# 35 Blattabacterium cuenoti_G
# 36 Blattabacterium cuenoti_P
# 37 Blattabacterium cuenoti_N
# 38 Blattabacterium cuenoti_Q
# 39 Blattabacterium cuenoti_S
# 40 Blattabacterium cuenoti_T
# 41 Blattabacterium cuenoti_M
# 42 Blattabacterium cuenoti_B
# 43 Blattabacterium cuenoti_AB
# 44 Blattabacterium cuenoti_E
# 45 Blattabacterium cuenoti_AE
# 46 Blattabacterium cuenoti_U
# 47 Blattabacterium cuenoti_AC
# 48 Blattabacterium cuenoti_AK
# 49 Blattabacterium cuenoti_J
# 50 Blattabacterium cuenoti_V
# 51 Myxococcus sp017301735
# 52 Myxococcus sp020037125
# 53 Myxococcus sp024198175
# 54 Myxococcus virescens
# 55 Myxococcus xanthus
# 56 Actinomyces sp900323545
# 57 Actinomyces viscosus

# %%
# Stop here
